# %%
def add(a,b):
    print(a+b)
add (2,3)
# Out:
# 5

# %%
def add(a,b):
    print(a+b)
add (2,3)
# Out:
# 5

# %%
square = lambda x: x*x
print(square(4))
# Out:
# 16

# %%
square = lambda x:x*x
print (square (5))
# Out:
# 25

# %%
add = lambda a, b: print(a + b)
add(2, 3)
# Out:
# 5
